# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
#%matplotlib inline
# Load the dataset
iris = sns.load_dataset('iris')
# Display first 5 rows
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.datasets import load_iris
iris_data = load_iris()

# %%
type(iris_data)
# Out:
# sklearn.utils._bunch.Bunch

# %%
iris_data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
iris_data['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
iris_data['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
iris_data['data']
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
iris_df = pd.DataFrame(data = iris_data['data'], columns = iris_data['feature_names'])
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
iris_df = pd.DataFrame(data = iris_data['data'], columns = iris_data['feature_names'])
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
from PIL import Image
img=Image.open(r"C:\Users\sange\Downloads\iris.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1024x367>

# %%
df = pd.read_csv(r"C:\Users\sange\Downloads\Iris_Data.csv")
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Dataset shape
print(f"Dataset shape: {iris.shape}")
# Basic information
iris.info()
# Out:
# Dataset shape: (150, 5)
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
# Check for missing values
print("\nMissing values per column:")
print(iris.isnull().sum())
# Out:
# Missing values per column:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Dataset Duplicate Value Count
dup = df.duplicated().sum()
print(f'number of duplicated rows are {dup}')
# Out:
# number of duplicated rows are 1

# %%
df.Species.value_counts()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
#data preprocessing
from sklearn.preprocessing import LabelEncoder
# Encode the categorical columns
# Create a LabelEncoder object
le = LabelEncoder() 

# Encode the 'Species' column to convert the species names to numerical labels
df['Species'] = le.fit_transform(df['Species'])
# Check the unique values in the 'Species' column after encoding
unique_species = df['Species'].unique()
# Display the unique encoded values
print("Encoded Species Values:")
print(unique_species) # 'Iris-setosa' == 0, 'Iris-versicolor' == 1, 'Iris-virginica' == 2
# Out:
# Encoded Species Values:
# [0 1 2]

# %%
# Species distribution
print("\nSpecies distribution:")
print(iris['species'].value_counts())
# Out:
# Species distribution:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
#Create subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# Plot distributions
sns.histplot(iris['sepal_length'], kde=True, ax=axes[0, 0], color='green')



axes[0, 0].set_title('Sepal Length Distribution')
sns.histplot(iris['sepal_width'], kde=True, ax=axes[0, 1], color='skyblue')
axes[0, 1].set_title('Sepal Width Distribution')
sns.histplot(iris['petal_length'], kde=True, ax=axes[1, 0], color='orange')
axes[1, 0].set_title('Petal Length Distribution')
sns.histplot(iris['petal_width'], kde=True, ax=axes[1, 1], color='red')
axes[1, 1].set_title('Petal Width Distribution')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=iris.drop('species', axis=1))
plt.title('Boxplot of All Numerical Features')
plt.ylabel('Centimeters (cm)')
plt.show()

# %%
#default theme
sns.set(context='notebook', style='darkgrid', palette='colorblind', font='sans-serif', font_scale=1, color_codes=True, rc=None)
matplotlib.rcParams['figure.figsize'] =[8,8]
matplotlib.rcParams.update({'font.size': 15})
matplotlib.rcParams['font.family'] = 'sans-serif'
sns.set_style('darkgrid')

# %%
sns.countplot(x='Species',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
df['Species'].value_counts().plot.pie(explode=[0.1,0.1,0.1],autopct='%1.1f%%'
,shadow=True, figsize=(10,8))
plt.show()

# %%
df.hist(edgecolor='black',figsize=(12,12))
plt.show()

# %%
#visualization code for distribution of numerical variables
# Create a figure with subplots
plt.figure(figsize=(8, 6))
plt.suptitle('Distribution of Iris Flower Measurements', fontsize=14)
# Create a 2x2 grid of subplots
plt.subplot(2, 2, 1) # Subplot 1 (Top-Left)
plt.hist(df['Sepal.Length'])
plt.title('Sepal Length Distribution')
plt.subplot(2, 2, 2) # Subplot 2 (Top-Right)
plt.hist(df['Sepal.Width'])
plt.title('Sepal Width Distribution')
plt.subplot(2, 2, 3) # Subplot 3 (Bottom-Left)
plt.hist(df['Petal.Length'])
plt.title('Petal Length Distribution')
plt.subplot(2, 2, 4) # Subplot 4 (Bottom-Right)

plt.hist(df['Petal.Width']) 

plt.title('Petal Width Distribution')
# Display the subplots
plt.tight_layout() # Helps in adjusting the layout
plt.show()

# %%
# We can look at an individual feature in Seaborn through a boxplot
sns.boxplot(x="Species", y="Petal.Length", data=df)
# Out:
# <Axes: xlabel='Species', ylabel='Petal.Length'>

# %%
ax = sns.boxplot(x="Species", y="Petal.Length", data=df)
ax = sns.stripplot(x="Species", y="Petal.Length", data=df, jitter=True, edgecolor="gray")
# Out:
# C:\Users\sange\AppData\Local\Temp\ipykernel_3928\3526364244.py:2: FutureWarning: Use "auto" to set automatic grayscale colors. From v0.14.0, "gray" will default to matplotlib's definition.
#   ax = sns.stripplot(x="Species", y="Petal.Length", data=df, jitter=True, edgecolor="gray")

# %%
# Create the figure
plt.figure(figsize=(8, 6))
species = df['Species'].unique()
colors = ['red', 'green', 'blue']
# Scatter plot for each species
for i in range(len(species)):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['Sepal.Length'], x['Sepal.Width'], c=colors[i], label=species[i])
# Add labels and legend
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs Width by Species')
plt.legend()
# Show plot
plt.show()

# %%
df.plot(kind="scatter", x="Sepal.Length", y="Sepal.Width")
# Out:
# <Axes: xlabel='Sepal.Length', ylabel='Sepal.Width'>

# %%
sns.pairplot(df , hue='Species');

# %%
sns.pairplot(df , hue='Sepal.Width');

# %%
sns.pairplot(iris, hue='species', palette='viridis', height=2.5)
plt.suptitle('Pairwise Relationships by Species', y=1.02)
plt.show()

# %%
# Calculate correlation
corr = iris.drop('species', axis=1).corr()
# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0, fmt=".2f")
plt.title('Feature Correlation Heatmap')
plt.show()

# %%
df.corr()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width   Species
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941  0.782561
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126 -0.426658
# Petal.Length      0.871754    -0.428440      1.000000     0.962865  0.949035
# Petal.Width       0.817941    -0.366126      0.962865     1.000000  0.956547
# Species           0.782561    -0.426658      0.949035     0.956547  1.000000

# %%
df.iloc[:, :-1].corr().style.background_gradient(cmap='coolwarm').format(precision=2)
# Out:
# <style type="text/css">
# #T_a8318_row0_col0, #T_a8318_row1_col1, #T_a8318_row2_col2, #T_a8318_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a8318_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_a8318_row0_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_a8318_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_a8318_row1_col0, #T_a8318_row1_col2, #T_a8318_row1_col3, #T_a8318_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_a8318_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_a8318_row2_col3, #T_a8318_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_a8318_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_a8318_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a8318">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8318_level0_col0" class="col_heading level0 col0" >Sepal.Length</th>
#       <th id="T_a8318_level0_col1" class="col_heading level0 col1" >Sepal.Width</th>
#       <th id="T_a8318_level0_col2" class="col_heading level0 col2" >Petal.Length</th>
#       <th id="T_a8318_level0_col3" class="col_heading level0 col3" >Petal.Width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8318_level0_row0" class="row_heading level0 row0" >Sepal.Length</th>
#       <td id="T_a8318_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_a8318_row0_col1" class="data row0 col1" >-0.12</td>
#       <td id="T_a8318_row0_col2" class="data row0 col2" >0.87</td>
#       <td id="T_a8318_row0_col3" class="data row0 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_a8318_level0_row1" class="row_heading level0 row1" >Sepal.Width</th>
#       <td id="T_a8318_row1_col0" class="data row1 col0" >-0.12</td>
#       <td id="T_a8318_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_a8318_row1_col2" class="data row1 col2" >-0.43</td>
#       <td id="T_a8318_row1_col3" class="data row1 col3" >-0.37</td>
#     </tr>
#     <tr>
#       <th id="T_a8318_level0_row2" class="row_heading level0 row2" >Petal.Length</th>
#       <td id="T_a8318_row2_col0" class="data row2 col0" >0.87</td>
#       <td id="T_a8318_row2_col1" class="data row2 col1" >-0.43</td>
#       <td id="T_a8318_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_a8318_row2_col3" class="data row2 col3" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_a8318_level0_row3" class="row_heading level0 row3" >Petal.Width</th>
#       <td id="T_a8318_row3_col0" class="data row3 col0" >0.82</td>
#       <td id="T_a8318_row3_col1" class="data row3 col1" >-0.37</td>
#       <td id="T_a8318_row3_col2" class="data row3 col2" >0.96</td>
#       <td id="T_a8318_row3_col3" class="data row3 col3" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# Plot distributions by species
sns.boxplot(x='species', y='sepal_length', data=iris, ax=axes[0, 0], palette='Set2')
axes[0, 0].set_title('Sepal Length by Species')
sns.boxplot(x='species', y='sepal_width', data=iris, ax=axes[0, 1], palette='Set2')
axes[0, 1].set_title('Sepal Width by Species')
sns.boxplot(x='species', y='petal_length', data=iris, ax=axes[1, 0], palette='Set2')
axes[1, 0].set_title('Petal Length by Species')
sns.boxplot(x='species', y='petal_width', data=iris, ax=axes[1, 1], palette='Set2')
axes[1, 1].set_title('Petal Width by Species')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\sange\AppData\Local\Temp\ipykernel_3928\4165190797.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_length', data=iris, ax=axes[0, 0], palette='Set2')
# C:\Users\sange\AppData\Local\Temp\ipykernel_3928\4165190797.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='sepal_width', data=iris, ax=axes[0, 1], palette='Set2')
# C:\Users\sange\AppData\Local\Temp\ipykernel_3928\4165190797.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='petal_length', data=iris, ax=axes[1, 0], palette='Set2')
# C:\Users\sange\AppData\Local\Temp\ipykernel_3928\4165190797.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='species', y='petal_width', data=iris, ax=axes[1, 1], palette='Set2')

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='species', y='petal_length', data=iris, inner='quartile', palette='pastel')
plt.title('Petal Length Distribution by Species')
plt.show()
# Out:
# C:\Users\sange\AppData\Local\Temp\ipykernel_3928\3742048603.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='species', y='petal_length', data=iris, inner='quartile', palette='pastel')

# %%
from pandas.plotting import andrews_curves
plt.figure(figsize=(10, 6))
andrews_curves(iris, 'species', colormap='viridis')
plt.title('Andrews Curves for Iris Dataset')
plt.show()

# %%
from pandas.plotting import parallel_coordinates
plt.figure(figsize=(10, 6))
parallel_coordinates(iris, 'species', colormap='viridis')
plt.title('Parallel Coordinates Plot for Iris Dataset')
plt.show()
